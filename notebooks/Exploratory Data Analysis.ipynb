# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../input/cleaned_data.csv')

# %%
df.shape
# Out:
# (1562, 18)

# %%
df.head()
# Out:
#        country  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
# 3  Afghanistan  2011     3.831719            7.415019        0.521104
# 4  Afghanistan  2012     3.782938            7.517126        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         49.209663                      0.718114    0.181819
# 1                         49.624432                      0.678896    0.203614
# 2                         50.008961                      0.600127    0.137630
# 3                         50.367298                      0.495901    0.175329
# 4                         50.709263                      0.530935    0.247159
#
#    Perceptions of corruption  Positive affect  Negative affect  \
# ...

# %%
df.shape
# Out:
# (1562, 18)

# %%
summary = df.drop(['year'], axis=1).describe().transpose()
summary
# Out:
#                                                      count       mean  \
# Life Ladder                                         1562.0   5.433676
# Log GDP per capita                                  1550.0   9.221842
# Social support                                      1561.0   0.811197
# Healthy life expectancy at birth                    1553.0  62.249887
# Freedom to make life choices                        1562.0   0.729252
# Generosity                                          1549.0   0.000421
# Perceptions of corruption                           1540.0   0.746473
# Positive affect                                     1561.0   0.708553
# Negative affect                                     1562.0   0.263312
# Confidence in national government                   1488.0   0.490694
# Democratic Quality                                  1530.0  -0.125141
# Delivery Quality                                    1530.0   0.005747
# ...

# %%
summary.to_csv('../app/data/summary_stats.csv', index_label='attribute')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect',
#        'Confidence in national government', 'Democratic Quality',
#        'Delivery Quality', 'Standard deviation of ladder by country-year',
#        'Standard deviation/Mean of ladder by country-year',
#        'GINI index (World Bank estimate), average 2000-15',
#        'gini of household income reported in Gallup, by wp5-year'],
#       dtype='object')

# %%
happiest2017 = df.loc[df['year'] == 2017].sort_values('Life Ladder', ascending=False)[0:5]['country'].values
mask = df.country.map(lambda c: c in happiest2017)

# %%
plt.figure(figsize=(12, 6))

sns.lineplot(x='year', y='Life Ladder', hue='country', data=df[mask])
plt.ylabel('Happiness Score')

plt.show()

# %%
df.year
# Out:
# 0       2008
# 1       2009
# 2       2010
# 3       2011
# 4       2012
# 5       2013
# 6       2014
# 7       2015
# 8       2016
# 9       2017
# 10      2007
# 11      2009
# 12      2010
# 13      2011
# 14      2012
# 15      2013
# 16      2014
# 17      2015
# 18      2016
# 19      2017
# 20      2010
# 21      2011
# 22      2012
# 23      2014
# 24      2016
# 25      2017
# 26      2011
# 27      2012
# 28      2013
# 29      2014
#         ...
# 1532    2011
# 1533    2012
# 1534    2013
# 1535    2014
# 1536    2015
# 1537    2016
# 1538    2017
# 1539    2006
# 1540    2007
# 1541    2008
# 1542    2009
# 1543    2011
# 1544    2012
# 1545    2013
# 1546    2014
# 1547    2015
# 1548    2016
# 1549    2017
# 1550    2006
# 1551    2007
# 1552    2008
# 1553    2009
# 1554    2010
# 1555    2011
# 1556    2012
# 1557    2013
# 1558    2014
# 1559    2015
# 1560    2016
# 1561    2017
# Name: year, Length: 1562, dtype: int64

# %%
plt.figure(figsize=(12, 6))

sns.boxplot(x='year', y='Life Ladder',data=df)
plt.ylabel('Happiness Score')

plt.show()

# %%
plt.figure(figsize=(12, 6))


happiest2017 = df.loc[df['year'] == 2017].sort_values('Life Ladder', ascending=False)[0:10]['country'].values
mask = df.country.map(lambda c: c in happiest2017) & (df['year'] == 2017)

sns.barplot(x='country', y='Life Ladder',data=df[mask].sort_values('Life Ladder', ascending=False))
plt.ylabel('Happiness Score')

plt.show()

# %%
# unhappiest countries

plt.figure(figsize=(12, 6))

happiest2017 = df.loc[df['year'] == 2017].sort_values('Life Ladder', ascending=True)[0:10]['country'].values
mask = df.country.map(lambda c: c in happiest2017) & (df['year'] == 2017)

data = df[mask].sort_values('Life Ladder', ascending=True)
data['country'] = data.cou
sns.barplot(x='country', y='Life Ladder', data=)
plt.ylabel('Happiness Score')

plt.show()

# %%
happiest2017
# Out:
# array(['Afghanistan', 'South Sudan', 'Yemen', 'Tanzania', 'Malawi',
#        'Central African Republic', 'Botswana', 'Zimbabwe', 'Haiti',
#        'Egypt'], dtype=object)

# %%
df[mask]
# Out:
#                        country  year  Life Ladder  Log GDP per capita  \
# 0                  Afghanistan  2008     3.723590            7.168690
# 1                  Afghanistan  2009     4.401778            7.333790
# 2                  Afghanistan  2010     4.758381            7.386629
# 3                  Afghanistan  2011     3.831719            7.415019
# 4                  Afghanistan  2012     3.782938            7.517126
# 5                  Afghanistan  2013     3.572100            7.503376
# 6                  Afghanistan  2014     3.130896            7.484583
# 7                  Afghanistan  2015     3.982855            7.466215
# 8                  Afghanistan  2016     4.220169            7.461401
# 9                  Afghanistan  2017     2.661718            7.460144
# 167                   Botswana  2006     4.739367            9.422458
# 168                   Botswana  2008     5.451147            9.530127
# ...

# %%
plt.figure(figsize=(12, 12))

for i, x in enumerate(['Social support', 'Healthy life expectancy at birth',
       'Freedom to make life choices', 'Generosity']):
    plt.subplot(2, 2, i + 1)
    sns.regplot(x=x, y='Life Ladder', data=df.loc[df['year'] == 2017])
    plt.ylabel('Happiness Score')

plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df[['Life Ladder', 'Perceptions of corruption']].loc[df['year'] == 2017].isna().sum()
# Out:
# Life Ladder                  0
# Perceptions of corruption    2
# dtype: int64

# %%
plt.figure(figsize=(30, 30))

sns.pairplot(df[['Social support', 'Healthy life expectancy at birth',
       'Freedom to make life choices', 'Generosity']]
             .loc[df['year'] == 2017].dropna())

plt.show()

# %%
plt.figure(figsize=(6, 6))

sns.distplot(df['Life Ladder'])

plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
